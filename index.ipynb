# %% [markdown]
# <a href="https://colab.research.google.com/github/Yasser-Baleghi/hands-on-dl-image-processing/blob/master/chapter_01/01_introduction.ipynb" target="_parent">
#     <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>
#
# # Hands-on Deep Learning based Image Processing using Google Colab
#
# ### Welcome! This is the master index for all notebooks in this book.

# %% [markdown]
# Click any link below to open that chapter directly in Google Colab.
#
# ---
#
# ## 📚 Table of Contents
#
# ### Part I: Foundations of Digital Image Processing
#
# | Chapter | Title | Open in Colab |
# | :---: | :--- | :---: |
# | 1 | Entering the Image Processing World Through Google Colab Gates | [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Yasser-Baleghi/hands-on-dl-image-processing/blob/master/index.ipynb/chapter_01/01_introduction.ipynb) |
# | 2 | Mathematical Foundations – Pixels, Histograms, and Intensity Transformations | [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Yasser-Baleghi/hands-on-dl-image-processing/blob/master/chapter_02/02_pixel_histograms.ipynb) |
# | 3 | Spatial Filtering – The Mathematics of Neighbors | [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Yasser-Baleghi/hands-on-dl-image-processing/blob/master/chapter_03/03_convolution_filters.ipynb) |
# | 4 | Frequency Domain Processing – The Fourier Transform in Action | [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Yasser-Baleghi/hands-on-dl-image-processing/blob/master/chapter_04/04_fourier_transform.ipynb) |
# | 5 | Morphological Operations – Shape Processing Mathematics | [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Yasser-Baleghi/hands-on-dl-image-processing/blob/master/chapter_05/05_morphology.ipynb) |
# | 6 | Image Segmentation – Classical Approaches | [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Yasser-Baleghi/hands-on-dl-image-processing/blob/master/chapter_06/06_segmentation.ipynb) |
#
# ### Part II: Transition to Deep Learning
#
# | Chapter | Title | Open in Colab |
# | :---: | :--- | :---: |
# | 7 | Neural Networks – The Building Blocks | [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Yasser-Baleghi/hands-on-dl-image-processing/blob/master/chapter_07/07_neural_networks.ipynb) |
# | 8 | Convolutional Neural Networks – Theory and Implementation | [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Yasser-Baleghi/hands-on-dl-image-processing/blob/master/chapter_08/08_cnn.ipynb) |
# | 9 | Transfer Learning – Leveraging Pre-Trained Models | [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Yasser-Baleghi/hands-on-dl-image-processing/blob/master/chapter_09/09_transfer_learning.ipynb) |
#
# ### Part III: Deep Learning for Core Image Processing Tasks
#
# | Chapter | Title | Open in Colab |
# | :---: | :--- | :---: |
# | 10 | Image Denoising – From Classical to Deep Learning | [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Yasser-Baleghi/hands-on-dl-image-processing/blob/master/chapter_10/10_denoising.ipynb) |
# | 11 | Image Enhancement – Super-Resolution and Low-Light Improvement | [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Yasser-Baleghi/hands-on-dl-image-processing/blob/master/chapter_11/11_super_resolution.ipynb) |
# | 12 | Image Segmentation – Deep Learning Revolution | [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Yasser-Baleghi/hands-on-dl-image-processing/blob/master/chapter_12/12_deep_segmentation.ipynb) |
# | 13 | Object Detection – The YOLO Era | [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Yasser-Baleghi/hands-on-dl-image-processing/blob/master/chapter_13/13_object_detection.ipynb) |
#
# ### Part IV: Advanced and Modern Techniques
#
# | Chapter | Title | Open in Colab |
# | :---: | :--- | :---: |
# | 14 | Generative Adversarial Networks (GANs) | [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Yasser-Baleghi/hands-on-dl-image-processing/blob/master/chapter_14/14_gans.ipynb) |
# | 15 | Vision Transformers (ViT) and Attention Mechanisms | [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Yasser-Baleghi/hands-on-dl-image-processing/blob/master/chapter_15/15_vision_transformers.ipynb) |
# | 16 | Diffusion Models – The New Frontier in Image Generation | [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Yasser-Baleghi/hands-on-dl-image-processing/blob/master/chapter_16/16_diffusion_models.ipynb) |
#
# ### Part V: Deployment and Real-World Impact
#
# | Chapter | Title | Open in Colab |
# | :---: | :--- | :---: |
# | 17 | From Colab to Production – Deploying Your Models | [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Yasser-Baleghi/hands-on-dl-image-processing/blob/master/chapter_17/17_deployment.ipynb) |
#
# ### Part VI: Capstone Projects
#
# | Chapter | Title | Open in Colab |
# | :---: | :--- | :---: |
# | 18 | Medical Image Analysis – From Data to Diagnosis | [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Yasser-Baleghi/hands-on-dl-image-processing/blob/master/chapter_18/18_medical_capstone.ipynb) |
# | 19 | Autonomous Driving Perception – Detection and Segmentation | [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Yasser-Baleghi/hands-on-dl-image-processing/blob/master/chapter_19/19_driving_capstone.ipynb) |
# | 20 | Creative AI – Style Transfer, Colorization, and AR Filters | [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Yasser-Baleghi/hands-on-dl-image-processing/blob/master/chapter_20/20_creative_capstone.ipynb) |
#
# ---
#
# ## 📄 Citation
#
# If you use this repository in your research or teaching, please cite: [To Be Pulished Soon!]

# %% [markdown]
# ---
#
# **Happy Learning! 🚀**
